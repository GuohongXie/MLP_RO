# %%
import numpy as np
import pandas as pd  
import os
import random
from sklearn import preprocessing

# %%
csv_e = r'../../data/raw_earlier_csv_all_734/12.csv' 
csv_l = r'../../data/raw_later_csv_all_734/12.csv'
#train_csv_inside = r'../../data/merged_csv_inside/train_inside_csv_650/train_inside_csv_650.csv'
#train_csv_outside = r'../../data/merged_csv_outside/train_outside_csv_650/train_outside_csv_650.csv'

# valid_csv_all = r'../../data/merged_csv/valid_data_csv_74/valid_data_csv_74.csv'
# valid_csv_inside = r'../../data/merged_csv_inside/valid_inside_csv_74/valid_inside_csv_74.csv'
# valid_csv_outside = r'../../data/merged_csv_outside/valid_outside_csv_74/valid_outside_csv_74.csv'

# %%
df_e = pd.read_csv(csv_e,\
                         header = None,\
                         names=['x','y','z','D1A','D2A','D1B','D2B','angle','Qtot','Dtot','U','P','C'],\
                         encoding="utf8")  #编码默认UTF-8，若乱码自行更改

df_l = pd.read_csv(csv_l,\
                         header = None,\
                         names=['x','y','z','D1A','D2A','D1B','D2B','angle','Qtot','Dtot','U','P','C'],\
                         encoding="utf8")  #编码默认UTF-8，若乱码自行更改
print("the lenth of df_train_u is %d"%len(df_e))
print("the lenth of df_train_Qtot is %d"%len(df_l))
#print("the lenth of df_train_inside is %d"%len(df_train_inside))
#print("the lenth of df_train_outside is %d"%len(df_train_outside))
# Out:
# the lenth of df_train_u is 202717
# the lenth of df_train_Qtot is 252419

# %%
print(df_e.max())
print(df_e.min())
print(df_e.max() - df_e.min())
# Out:
# x           0.026853
# y           0.000720
# z           0.000403
# D1A         0.000450
# D2A         0.000225
# D1B         0.000525
# D2B         0.000225
# angle      30.000000
# Qtot      226.730000
# Dtot        0.000815
# U           0.350110
# P         377.820000
# C        1201.900000
# dtype: float64
# x          0.000000
# y         -0.000720
# z         -0.000403
# D1A        0.000450
# D2A        0.000225
# D1B        0.000525
# D2B        0.000225
# angle     30.000000
# Qtot     226.730000
# Dtot       0.000815
# U          0.000000
# P        -14.692000
# C        600.060000
# dtype: float64
# x          0.026853
# y          0.001439
# z          0.000805
# D1A        0.000000
# D2A        0.000000
# D1B        0.000000
# D2B        0.000000
# angle      0.000000
# Qtot       0.000000
# Dtot       0.000000
# U          0.350110
# P        392.512000
# C        601.840000
# dtype: float64

# %%
print(df_l.max())
print(df_l.min())
print(df_l.max() - df_l.min())
# Out:
# x           0.026853
# y           0.000720
# z           0.000403
# D1A         0.000450
# D2A         0.000225
# D1B         0.000525
# D2B         0.000225
# angle      30.000000
# Qtot      226.730000
# Dtot        0.000815
# U           0.350000
# P         377.820000
# C        1201.900000
# dtype: float64
# x       -2.450000e-20
# y       -7.195200e-04
# z       -4.025000e-04
# D1A      4.500000e-04
# D2A      2.250000e-04
# D1B      5.250000e-04
# D2B      2.250000e-04
# angle    3.000000e+01
# Qtot     2.267300e+02
# Dtot     8.150000e-04
# U        0.000000e+00
# P       -1.469200e+01
# C        6.100000e+02
# dtype: float64
# x          0.026853
# y          0.001439
# z          0.000805
# D1A        0.000000
# D2A        0.000000
# D1B        0.000000
# D2B        0.000000
# angle      0.000000
# Qtot       0.000000
# Dtot       0.000000
# U          0.350000
# P        392.512000
# C        591.900000
# dtype: float64

# %%
B=df_e['x'].hist().get_figure()

# %%
A=df_l['x'].hist().get_figure()

# %%
B=df_e['y'].hist().get_figure()

# %%
A=df_l['y'].hist().get_figure()

# %%
B=df_e['z'].hist().get_figure()

# %%
A=df_l['z'].hist().get_figure()

# %%
B=df_e['U'].hist().get_figure()

# %%
A=df_l['U'].hist().get_figure()

# %%
B=df_e['P'].hist().get_figure()

# %%
A=df_l['P'].hist().get_figure()

# %%
B=df_e['C'].hist().get_figure()

# %%
A=df_l['C'].hist().get_figure()
